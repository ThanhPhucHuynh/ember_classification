# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

ember_df = pd.read_csv("/content/drive/MyDrive/Data_malware/metaData_features_label_1.csv")
ember_df.shape
# Out:
# (400000, 800)

# %%
ember_df.head(5)
# Out:
#           0         1  ...                                             sha256  fold
# 0  0.021800  0.006362  ...  000262d3f5a33f394ce0febea6eebf0fad8c5e7a1e37c5...   138
# 1  0.264554  0.010065  ...  000392132cfb94be17945f5491dbaf2ee2dab9373fa151...   143
# 2  0.020368  0.007115  ...  0004516e04da9ad037e630186ffc351f9c8af63d57a530...   149
# 3  0.241131  0.005274  ...  000578c7d1978b8360a8ec43e62fae8ce797d5394a7805...   109
# 4  0.041172  0.003020  ...  000b567542dfe9de9099666894679810af426a6a43129f...   164
#
# [5 rows x 800 columns]

# %%
# 1 - Agent
f_Agent = open("/content/drive/MyDrive/Data_malware/data_group/Agent");
Agent = f_Agent.read();
Agent = Agent.split(" \n");
print(" len Agent: ", len(Agent))

# 2 - Trojan
f_Trojan = open("/content/drive/MyDrive/Data_malware/data_group/newTrojan");
Trojan = f_Trojan.read();
Trojan = Trojan.split(" \n");
print(" len Trojan: ", len(Trojan))
 
# 3 - Adware
f_Adware = open("/content/drive/MyDrive/Data_malware/data_group/Adware");
Adware = f_Adware.read();
Adware = Adware.split(" \n");
print(" len Adware: ", len(Adware))

# 4 - Backdoor
f_Backdoor = open("/content/drive/MyDrive/Data_malware/data_group/Backdoor");
Backdoor = f_Backdoor.read();
Backdoor = Backdoor.split(" \n");
print(" len Backdoor: ", len(Backdoor))

# 5 - Downloader
f_Downloader = open("/content/drive/MyDrive/Data_malware/data_group/Downloader");
Downloader = f_Downloader.read();
Downloader = Downloader.split(" \n");
print(" len Downloader: ", len(Downloader))

# 6
f_Virus = open("/content/drive/MyDrive/Data_malware/data_group/Virus");
Virus = f_Virus.read();
Virus = Virus.split(" \n");
print(" len Virus: ", len(Virus))

# 7 - Worms
f_Worms = open("/content/drive/MyDrive/Data_malware/data_group/Worms");
Worms = f_Worms.read();
Worms = Worms.split(" \n");
print(" len Worms: ", len(Worms))

# 8 - Dropper
f_Dropper = open("/content/drive/MyDrive/Data_malware/data_group/Dropper");
Dropper = f_Dropper.read();
Dropper = Dropper.split(" \n");
print(" len Dropper: ", len(Dropper))

# 9 - Others
f_Ransomware = open("/content/drive/MyDrive/Data_malware/data_group/Ransomware");
Ransomware = f_Ransomware.read();
Ransomware = Ransomware.split(" \n");
print(" len Ransomware: ", len(Ransomware))

# 10 - Spyware
f_Spyware = open("/content/drive/MyDrive/Data_malware/data_group/Spyware");
Spyware = f_Spyware.read();
Spyware = Spyware.split(" \n");
print(" len Spyware: ", len(Spyware))
# Out:
#  len Agent:  2041
#  len Trojan:  2960
#  len Adware:  1415
#  len Backdoor:  2007
#  len Downloader:  442
#  len Virus:  2597
#  len Worms:  1253
#  len Dropper:  141
#  len Ransomware:  82
#  len Spyware:  46

# %%
f_Ransomware.close();
f_Agent.close();
f_Trojan.close();
f_Adware.close();
f_Backdoor.close();
f_Downloader.close();
f_Virus.close();
f_Worms.close();
f_Dropper.close();
f_Spyware.close();

# %%
import os
os.mkdir('/content/data_group_csv')

d1 = ember_df.loc[ember_df['sha256'].isin(Adware)]
d1["className"] = "Adware"
d1.to_csv('/content/data_group_csv/Adware.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
d2 = ember_df.loc[ember_df['sha256'].isin(Downloader)]
d2["className"] = "Downloader"
d2.to_csv('/content/data_group_csv/Downloader.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d3 = ember_df.loc[ember_df['sha256'].isin(Worms)]
d3["className"] = "Worms"
d3.to_csv('/content/data_group_csv/Worms.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d4 = ember_df.loc[ember_df['sha256'].isin(Virus)]
d4["className"] = "Virus"
d4.to_csv('/content/data_group_csv/Virus.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d5 = ember_df.loc[ember_df['sha256'].isin(Spyware)]
d5["className"] = "Spyware"
d5.to_csv('/content/data_group_csv/Spyware.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d6 = ember_df.loc[ember_df['sha256'].isin(Backdoor)]
d6["className"] = "Backdoor"
d6.to_csv('/content/data_group_csv/Backdoor.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d7 = ember_df.loc[ember_df['sha256'].isin(Trojan)]
d7["className"] = "Trojan"
d7.to_csv('/content/data_group_csv/Trojan.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d8 = ember_df.loc[ember_df['sha256'].isin(Agent)]
d8["className"] = "Agent"
d8.to_csv('/content/data_group_csv/Agent.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d9 = ember_df.loc[ember_df['sha256'].isin(Dropper)]
d9["className"] = "Dropper"
d9.to_csv('/content/data_group_csv/Dropper.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d10 = ember_df.loc[ember_df['sha256'].isin(Ransomware)]
d10["className"] = "Ransomware"
d10.to_csv('/content/data_group_csv/Ransomware.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
kt_duplicate = list(dict.fromkeys(d1['sha256']))
len(kt_duplicate)
# Out:
# 1414

# %%
new_data = pd.concat([d1,d2,d3,d4,d5,d6,d7,d8,d9,d10])
new_data.shape
# Out:
# (12974, 801)

# %%
new_data.head(5)
# Out:
#             0         1  ...  fold  className
# 113  0.348073  0.003285  ...    18     Adware
# 451  0.057452  0.005465  ...    52     Adware
# 495  0.036781  0.006217  ...    37     Adware
# 607  0.178206  0.009927  ...    16     Adware
# 756  0.169617  0.003844  ...    22     Adware
#
# [5 rows x 801 columns]

# %%
new_data.to_csv('/content/Data_Training.csv', index=False)

# %%
# !zip -r /content/data_group_csv.zip /content/data_group_csv/
# !cp /content/data_group_csv.zip /content/drive/MyDrive/Data_malware/data_group_csv.zip

# %%
# !cp /content/Data_Training.csv /content/drive/MyDrive/Data_malware/Data_Training.csv
